# %% [markdown]
# <a href="https://colab.research.google.com/github/Rojakarilakshmiprasanna/11239A077_Compilerdesign_E-Record/blob/main/Experimant_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def shift_reduce(expr):
    stack = []
    tokens = expr.split()
    while tokens:
        stack.append(tokens.pop(0))
        print("Shift:", stack)
        while len(stack) >= 3 and stack[-2] == '*':
            stack[-3:] = ['E']
            print("Reduce:", stack)
    return stack
print(shift_reduce("price + discount * quantity"))
# Out:
# Shift: ['price']
# Shift: ['price', '+']
# Shift: ['price', '+', 'discount']
# Shift: ['price', '+', 'discount', '*']
# Shift: ['price', '+', 'discount', '*', 'quantity']
# Reduce: ['price', '+', 'E']
# ['price', '+', 'E']
