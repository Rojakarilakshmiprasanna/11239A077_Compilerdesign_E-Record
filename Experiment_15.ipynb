# %% [markdown]
# <a href="https://colab.research.google.com/github/Rojakarilakshmiprasanna/11239A077_Compilerdesign_E-Record/blob/main/Experiment_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def generate_quadruples(expr):
    temp = 1
    quads = []
    stack = []
    output = []

    # Step 1: Convert infix → postfix (very simple)
    precedence = {'+':1, '*':2}
    operators = []

    tokens = expr.split()

    for token in tokens:
        if token.isalnum():
            output.append(token)
        elif token in precedence:
            while (operators and
                   precedence.get(operators[-1], 0) >= precedence[token]):
                output.append(operators.pop())
            operators.append(token)

    while operators:
        output.append(operators.pop())

    # Step 2: Generate quadruples from postfix
    for token in output:
        if token.isalnum():
            stack.append(token)
        else:
            op2 = stack.pop()
            op1 = stack.pop()
            temp_var = f"T{temp}"
            temp += 1
            quads.append((token, op1, op2, temp_var))
            stack.append(temp_var)

    return quads


print(generate_quadruples("burger + fries * 2"))
# Out:
# [('*', 'fries', '2', 'T1'), ('+', 'burger', 'T1', 'T2')]
